# %%
import sys
from pathlib import Path

root_dir = Path().resolve().parent
if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))

print(f"✓ Diretório raiz adicionado: {root_dir}")
# Out:
# ✓ Diretório raiz adicionado: C:\Users\MARCOS\Desktop\PPChat

# %%
from src.modules.ingestion.models.document import ProcessingConfig
from src.modules.ingestion.services.document_processor import DocumentProcessor

# Chunking semântico (usa recursivo como base + embeddings)
config = ProcessingConfig(
    chunk_size=500,
    chunk_overlap=100,
    min_length=50,
    embedding_model="sentence-transformers/all-MiniLM-L6-v2",
    similarity_threshold=0.75,
    max_chunk_size=1500
)

processor = DocumentProcessor(config)
chunks = processor.process_pdf("../src/data/documents/PPCENGSOFTWARE.pdf")

print(f"Total de chunks: {len(chunks)}")
print(f"\nPrimeiros 3 chunks:")
for chunk in chunks[:3]:
    print(f"\n--- Chunk {chunk.chunk_index} (Página {chunk.page_number}, {len(chunk.text)} chars) ---")
    print(chunk.text[:300] + "...")
# Out:
# Total de chunks: 656
#
# Primeiros 3 chunks:
#
# --- Chunk 0 (Página 1, 338 chars) ---
# Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 4 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA SÃO PAULO PROJETO PEDAGÓGICO DE CURSO - PPC BACHARELADO EM ENGENHARIA DE SOFTWARE VIGÊNCIA DEST...
#
# --- Chunk 1 (Página 2, 436 chars) ---
# Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 5 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE  Curso Criado pela Resolução CONSUP N.o 66/2022, de 04 de outubro de 2022.  Currículo de Referência do Curso Superior de Bacharelado em Engenharia ...
#
# --- Chunk 2 (Página 3, 494 chars) ---
# Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 6 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE AUTORIDADES INSTITUCIONAIS REITOR Silmário Batista dos Santos PRÓ-REITORIA DE PLANEJAMENTO E DESENVOLVIMENTO INSTITUCIONAL – PRO-DI Bruno Nogueira Luz ...
