# %%
import sys
from pathlib import Path

root_dir = Path().resolve().parent
if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))

print(f"✓ Diretório raiz adicionado: {root_dir}")
# Out:
# ✓ Diretório raiz adicionado: C:\Users\MARCOS\Desktop\PPChat

# %%
from src.modules.ingestion.models.document import ProcessingConfig
from src.modules.ingestion.services.document_processor import DocumentProcessor
config = ProcessingConfig(chunk_size=1000, chunk_overlap=200, min_length=50)

processor = DocumentProcessor(config)

chunks = processor.process_pdf("../src/data/documents/PPCENGSOFTWARE.pdf")
print(chunks)
# Out:
# [DocumentChunk(text='Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 4 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE INSTITUTO FEDERAL DE EDUCAÇÃO, CIÊNCIA E TECNOLOGIA SÃO PAULO PROJETO PEDAGÓGICO DE CURSO - PPC BACHARELADO EM ENGENHARIA DE SOFTWARE VIGÊNCIA DESTE PPC: 1º Sem/2023 Câmpus São Carlos', metadata={'producer': 'PyPDF2', 'creator': '', 'creationdate': '', 'source': '../src/data/documents/PPCENGSOFTWARE.pdf', 'file_path': '../src/data/documents/PPCENGSOFTWARE.pdf', 'total_pages': 151, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 0}, chunk_index=0, page_number=1), DocumentChunk(text='Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 5 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE \uf0b7 Curso Criado pela Resolução CONSUP N.º 66/2022, de 04 de outubro de 2022. \uf0b7 Currículo de Referência do Curso Superior de Bacharelado em Engenharia de Software, por meio da Resolução CONSUP 123/2021, de 03 de agosto de 2021. BACHARELADO EM ENGENHARIA DE SOFTWARE Câmpus São Carlos', metadata={'producer': 'PyPDF2', 'creator': '', 'creationdate': '', 'source': '../src/data/documents/PPCENGSOFTWARE.pdf', 'file_path': '../src/data/documents/PPCENGSOFTWARE.pdf', 'total_pages': 151, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 1}, chunk_index=1, page_number=2), DocumentChunk(text='Projeto Pedagógico do Curso Bacharelado em Engenharia de Software Modalidade: presencial 6 IFSP SÃO CARLOS BACHARELADO EM ENGENHARIA DE SOFTWARE AUTORIDADES INSTITUCIONAIS REITOR Silmário Batista dos Santos PRÓ-REITORIA DE PLANEJAMENTO E DESENVOLVIMENTO INSTITUCIONAL – PRO-DI Bruno Nogueira Luz PRÓ-REITORIA DE ADMINISTRAÇÃO – PRO-ADM José Roberto da Silva PRÓ-REITORIA DE ENSINO – PRE Carlos Eduardo Pinto Procópio PRÓ-REITORIA DE EXTENSÃO – PRO-EX Gabriela de Godoy Cravo Arduino PRÓ-REITORIA DE PESQUISA E PÓS-GRADUAÇÃO – PRP Adalton Masalu Ozaki AGÊNCIA DE INOVAÇÃO E TRANSFERÊNCIA DE TECNOLOGIAS – INOVA Alexandre Pereira Chahad ASSESSORIA DE RELAÇÕES INTERNACIONAIS - ARINTER Eduardo Antonio Modena DIRETORIA SISTÊMICA DE ASSUNTOS ESTUDANTIS - DAEST Reginaldo Vitor Pereira Diretor Geral do Câmpus Rivelli da Silva Pinto Diretoria Adjunta Educacional do Campus João Luiz Franco Coordenador de Curso Jorge Francisco Cutigi Núcleo Docente Estruturante Danilo Augusto Moschetto Jorge Francisco', metadata={'producer': 'PyPDF2', 'creator': '', 'creationdate': '', 'source': '../src/data/documents/PPCENGSOFTWARE.pdf', 'file_path': '../src/data/documents/PPCENGSOFTWARE.pdf', 'total_pages': 151, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, chunk_index=2, page_number=3), DocumentChunk(text='Câmpus Rivelli da Silva Pinto Diretoria Adjunta Educacional do Campus João Luiz Franco Coordenador de Curso Jorge Francisco Cutigi Núcleo Docente Estruturante Danilo Augusto Moschetto Jorge Francisco Cutigi José Luciano Santinho Lima Lucas Bueno Ruas de Oliveira Pedro Northon Nobile Rodrigo Elias Bianchi Sérgio Luisir Discola Junior Fábio Roberto Octaviano (suplente) João Luiz Franco (suplente) Colaboração Técnica Coordenadoria Sociopedagógica Carlos José de Almeida Pereira Caroline Silva Neubern de Oliveira Karyn Meyer', metadata={'producer': 'PyPDF2', 'creator': '', 'creationdate': '', 'source': '../src/data/documents/PPCENGSOFTWARE.pdf', 'file_path': '../src/data/documents/PPCENGSOFTWARE.pdf', 'total_pages': 151, 'format': 'PDF 1.3', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '', 'trapped': '', 'modDate': '', 'creationDate': '', 'page': 2}, chunk_index=3, page_number=3), DocumentChunk(text='Projeto Pedagógico do Curso Bacharelado em Engenharia de Soft ...
